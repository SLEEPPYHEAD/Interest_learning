# %%
from google.colab import drive    #For drive Mounting
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import math

# %% [markdown]
# ## **Data preprocessing:**

# %%
import pandas as pd
import numpy as np

# %%
target="Sleep Stage"

# %%
dataset[target].value_counts()
# Out:
# NREM    1798
# Wake     629
# REM      573
# Name: Sleep Stage, dtype: int64

# %% [markdown]
# ## **Data Reading:**

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Machine Learning/Sleep_data/EEG_HMC_Wake_NREM_REM_3000.csv')

# %%
dataset.head(10)
# Out:
#   Sleep Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 0        Wake         0.00051           8.74146        18.48195
# 1        Wake         0.00040          10.24000        17.48293
# 2        Wake         0.00036           9.74049        17.98244
# 3        Wake         0.00035          10.11512        17.60780
# 4        Wake         0.00033           9.74049        17.60780
# 5        Wake         0.00036          10.24000        16.98341
# 6        NREM         0.00034          10.11512        17.85756
# 7        NREM         0.00035          10.73951        17.60780
# 8        NREM         0.00035           9.36585        17.60780
# 9        NREM         0.00050          10.36488        16.60878
#
#    Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 0                17.48293         8.24195        0.00071         19.73073
# 1                16.85854        10.61463        0.00051         17.23317
# ...

# %%
dataset.tail(10)
# Out:
#      Sleep Stage  MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  \
# 2990        NREM         0.00080           7.49268        12.48780
# 2991        NREM         0.00113           7.61756        11.61366
# 2992        NREM         0.00103           7.86732        11.73854
# 2993        NREM         0.00119           7.61756        11.48878
# 2994        NREM         0.00104           7.36780        11.48878
# 2995        NREM         0.00089           7.36780        12.11317
# 2996        NREM         0.00085           7.49268        11.61366
# 2997        NREM         0.00097           7.36780        11.48878
# 2998        NREM         0.00110           7.49268        11.23902
# 2999        NREM         0.00101           7.36780        11.48878
#
#       Spectral Edge_Alpha_F4  PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  \
# 2990                10.86439         6.61854        0.00032          9.49073
# ...

# %%
dataset.shape # (row, column)
# Out:
# (3000, 76)

# %%
list(dataset.columns)
# Out:
# ['Sleep Stage',
#  'MeanP_Alpha_F4',
#  'MedianF_Alpha_F4',
#  'MeanF_Alpha_F4',
#  'Spectral Edge_Alpha_F4',
#  'PeakF_Alpha_F4',
#  'MeanP_Beta_F4',
#  'MedianF_Beta_F4',
#  'MeanF_Beta_F4',
#  'Spectral Edge_Beta_F4',
#  'PeakF_Beta_F4',
#  'MeanP_Theta_F4',
#  'MedianF_Theta_F4',
#  'MeanF_Theta_F4',
#  'Spectral Edge_Theta_F4',
#  'PeakF_Theta_F4',
#  'MeanP_Delta_F4',
#  'MedianF_Delta_F4',
#  'MeanF_Delta_F4',
#  'Spectral Edge_Delta_F4',
#  'PeakF_Delta_F4',
#  'MeanP_Gamma_F4',
#  'MedianF_Gamma_F4',
#  'MeanF_Gamma_F4',
#  'Spectral Edge_Gamma_F4',
#  'PeakF_Gamma_F4',
#  'MeanP_Alpha_C4',
#  'MedianF_Alpha_C4',
#  'MeanF_Alpha_C4',
#  'Spectral Edge_Alpha_C4',
#  'PeakF_Alpha_C4',
#  'MeanP_Beta_C4',
#  'MedianF_Beta_C4',
#  'MeanF_Beta_C4',
#  'Spectral Edge_Beta_C4',
#  'PeakF_Beta_C4',
#  'MeanP_Theta_C4',
#  'MedianF_Theta_C4',
#  'MeanF_Theta_C4',
#  'Spectral Edge_Theta_C4',
#  'PeakF_Theta_C4',
#  'MeanP_Delta_C4',
#  'MedianF_Delta_C4',
#  'MeanF_Delta_C4',
# ...

# %%
dataset.info() # showes the datatype of all data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sleep Stage             3000 non-null   object
#  1   MeanP_Alpha_F4          3000 non-null   float64
#  2   MedianF_Alpha_F4        3000 non-null   float64
#  3   MeanF_Alpha_F4          3000 non-null   float64
#  4   Spectral Edge_Alpha_F4  3000 non-null   float64
#  5   PeakF_Alpha_F4          3000 non-null   float64
#  6   MeanP_Beta_F4           3000 non-null   float64
#  7   MedianF_Beta_F4         3000 non-null   float64
#  8   MeanF_Beta_F4           3000 non-null   float64
#  9   Spectral Edge_Beta_F4   3000 non-null   float64
#  10  PeakF_Beta_F4           3000 non-null   float64
#  11  MeanP_Theta_F4          3000 non-null   float64
#  12  MedianF_Theta_F4        3000 non-null   float64
#  13  MeanF_Theta_F4          3000 non-null   float64
# ...

# %%
dataset.describe()
# Out:
#           MinTemp     MaxTemp    Rainfall  Evaporation    Sunshine  \
# count  366.000000  366.000000  366.000000   366.000000  363.000000
# mean     7.265574   20.550273    1.428415     4.521858    7.909366
# std      6.025800    6.690516    4.225800     2.669383    3.481517
# min     -5.300000    7.600000    0.000000     0.200000    0.000000
# 25%      2.300000   15.025000    0.000000     2.200000    5.950000
# 50%      7.450000   19.650000    0.000000     4.200000    8.600000
# 75%     12.500000   25.500000    0.200000     6.400000   10.500000
# max     20.900000   35.800000   39.800000    13.800000   13.600000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# count     364.000000    359.000000    366.000000   366.000000   366.000000
# mean       39.840659      9.651811     17.986339    72.035519    44.519126
# std        13.059807      7.951929      8.856997    13.137058    16.850947
# ...

# %%
dataset['WindGustDir'].unique() # showes unique values in that column
# Out:
# array(['NW', 'ENE', 'SSE', 'SE', 'E', 'S', 'N', 'WNW', 'ESE', 'NE', 'NNE',
#        'NNW', 'SW', 'W', 'WSW', 'SSW', nan], dtype=object)

# %%
dataset['WindGustDir'].value_counts() # shows the frequency of the datas of a column
# Out:
# NW     73
# NNW    44
# E      37
# WNW    35
# ENE    30
# ESE    23
# S      22
# N      21
# W      20
# NE     16
# SSE    12
# SE     12
# NNE     8
# SSW     5
# SW      3
# WSW     2
# Name: WindGustDir, dtype: int64

# %% [markdown]
# ## **Dropping null/nan Values**

# %%
dataset.dropna(axis=0, how='any', inplace = True)
dataset = dataset.reset_index(drop=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 76 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sleep Stage             3000 non-null   object
#  1   MeanP_Alpha_F4          3000 non-null   float64
#  2   MedianF_Alpha_F4        3000 non-null   float64
#  3   MeanF_Alpha_F4          3000 non-null   float64
#  4   Spectral Edge_Alpha_F4  3000 non-null   float64
#  5   PeakF_Alpha_F4          3000 non-null   float64
#  6   MeanP_Beta_F4           3000 non-null   float64
#  7   MedianF_Beta_F4         3000 non-null   float64
#  8   MeanF_Beta_F4           3000 non-null   float64
#  9   Spectral Edge_Beta_F4   3000 non-null   float64
#  10  PeakF_Beta_F4           3000 non-null   float64
#  11  MeanP_Theta_F4          3000 non-null   float64
#  12  MedianF_Theta_F4        3000 non-null   float64
#  13  MeanF_Theta_F4          3000 non-null   float64
# ...

# %% [markdown]
# ## **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

# %%
dataset[target].value_counts()
# Out:
# NREM    1798
# Wake     629
# REM      573
# Name: Sleep Stage, dtype: int64

# %%
dataset[target]=encoder.fit_transform(dataset[target])

# %%
dataset[target].value_counts()
# Out:
# 0    1798
# 2     629
# 1     573
# Name: Sleep Stage, dtype: int64

# %% [markdown]
# ### **PreProcessing:**

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

dataset['WindGustDir'] = encoder.fit_transform(dataset['WindGustDir'])
dataset['WindDir9am'] = encoder.fit_transform(dataset['WindDir9am'])
dataset['WindDir3pm'] = encoder.fit_transform(dataset['WindDir3pm'])
dataset['RainToday'] = encoder.fit_transform(dataset['RainToday'])
dataset['RainTomorrow'] = encoder.fit_transform(dataset['RainTomorrow'])

# %%
dataset.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3            7
# 1     14.0     26.9       3.6          4.4       9.7            1
# 2     13.7     23.4       3.6          5.8       3.3            7
# 3     13.3     15.5      39.8          7.2       9.1            7
# 4      7.6     16.1       2.8          5.6      10.6           10
#
#    WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0          12           7           6.0  ...           29
# 1           39.0           0          13           4.0  ...           36
# 2           85.0           3           5           6.0  ...           69
# 3           54.0          14          13          30.0  ...           56
# 4           50.0          10           2          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 328 entries, 0 to 327
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MinTemp        328 non-null    float64
#  1   MaxTemp        328 non-null    float64
#  2   Rainfall       328 non-null    float64
#  3   Evaporation    328 non-null    float64
#  4   Sunshine       328 non-null    float64
#  5   WindGustDir    328 non-null    int64
#  6   WindGustSpeed  328 non-null    float64
#  7   WindDir9am     328 non-null    int64
#  8   WindDir3pm     328 non-null    int64
#  9   WindSpeed9am   328 non-null    float64
#  10  WindSpeed3pm   328 non-null    int64
#  11  Humidity9am    328 non-null    int64
#  12  Humidity3pm    328 non-null    int64
#  13  Pressure9am    328 non-null    float64
#  14  Pressure3pm    328 non-null    float64
#  15  Cloud9am       328 non-null    int64
#  16  Cloud3pm       328 non-null    int64
# ...

# %% [markdown]
# ## **Data Spliting:**
#
# Loc-> Location
#
# df.loc[starting_row : ending_row,[column]]
#
# iloc->index location
# df.loc[starting_row:ending_row,starting_col:ending_col+1}

# %%
x=dataset.loc[:,dataset.columns!=target]

# %%
x.head()
# Out:
#    MeanP_Alpha_F4  MedianF_Alpha_F4  MeanF_Alpha_F4  Spectral Edge_Alpha_F4  \
# 0         0.00051           8.74146        18.48195                17.48293
# 1         0.00040          10.24000        17.48293                16.85854
# 2         0.00036           9.74049        17.98244                17.48293
# 3         0.00035          10.11512        17.60780                17.10829
# 4         0.00033           9.74049        17.60780                17.23317
#
#    PeakF_Alpha_F4  MeanP_Beta_F4  MedianF_Beta_F4  MeanF_Beta_F4  \
# 0         8.24195        0.00071         19.73073       29.84585
# 1        10.61463        0.00051         17.23317       26.34927
# 2         8.74146        0.00047         17.60780       25.47512
# 3         9.61561        0.00047         17.35805       26.47415
# 4         8.11707        0.00043         17.23317       25.84976
#
#    Spectral Edge_Beta_F4  PeakF_Beta_F4  ...  MeanP_Delta_O2  \
# ...

# %%
y=dataset[target]

# %%
y.head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Sleep Stage, dtype: int64

# %% [markdown]
# ## **Dataset spliting in testing and training**

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test =train_test_split(x,y,test_size=0.2)

# %% [markdown]
# ## **Training Phase**

# %% [markdown]
# ## **RandomForestt**

# %%
# %%time

from sklearn.ensemble import RandomForestClassifier   #importing libraries

clf = RandomForestClassifier()                        #creating method of algorithm 
                                                      #(Bracket a kichu na dile Default Parameter nibe)
                                                      #1st time model banaile default parameter newa valo
                                                      
clf.fit(x_train, y_train)                             #model fitting / data feeding / training

y_pred=clf.predict(x_test)                            #prediction
# Out:
# CPU times: user 1.33 s, sys: 0 ns, total: 1.33 s
# Wall time: 1.37 s

# %%
from sklearn.metrics import accuracy_score

score=accuracy_score(y_test,y_pred)

print(score)
# Out:
# 0.9266666666666666

# %%
rain_tom=clf.predict(x.loc[101:101,:])
print(rain_tom)
# Out:
# [0]

# %%
y[101]
# Out:
# 0

# %% [markdown]
# **Model save**

# %%
import joblib
joblib.dump(clf,"randomfores_rain_tom")
# Out:
# ['randomfores_rain_tom']

# %% [markdown]
# adaboost
#
# GradientBossting
#
# KNN
#
# Naive Byes

# %% [markdown]
# ## **AdaBoost**

# %%
from sklearn.ensemble import AdaBoostClassifier         #importing libraries


ada = AdaBoostClassifier()                              #creating method of algorithm 
                                                        #(Bracket a kichu na dile Default Parameter nibe)
                                                        #1st time model banaile default parameter newa valo

ada.fit(x_train, y_train)                               #model fitting / data feeding / training


y_pred = ada.predict(x_test)                                     #prediction



#clf.score(x, y)

# %%
from sklearn.metrics import accuracy_score

score=accuracy_score(y_test,y_pred)

print(score)
# Out:
# 0.79

# %% [markdown]
# ## **GradientBoosting**

# %%
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier

GB = GradientBoostingClassifier()
GB.fit(x_train, y_train)

y_pred = GB.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

score=accuracy_score(y_test,y_pred)

print(score)
# Out:
# 0.9366666666666666

# %% [markdown]
# ## **KNN**

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier()

neigh.fit(x_train, y_train)

y_pred =neigh.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

score=accuracy_score(y_test,y_pred)

print(score)
# Out:
# 0.8983333333333333

# %% [markdown]
# ## **Naive Byes**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(x_train,y_train)

y_pred = gnb.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

score=accuracy_score(y_test,y_pred)

print(score)
# Out:
# 0.705
